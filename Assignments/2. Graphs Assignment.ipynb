# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Emissions.csv")
df
# Out:
#          CO2 per capita      1997      1998      1999      2000      2001  \
# 0           Afghanistan  0.052333  0.048547  0.037446  0.034170  0.027255
# 1               Albania  0.499261  0.569226  0.971342  0.983553  1.047320
# 2               Algeria  3.015670  3.608258  3.060245  2.879528  2.720453
# 3               Andorra  7.061603  7.533543  8.022714  8.112345  7.897776
# 4                Angola  0.576991  0.556212  0.677617  0.685079  0.676339
# ..                  ...       ...       ...       ...       ...       ...
# 190  West Bank and Gaza  0.139027  0.202052  0.209713  0.247611  0.410766
# 191      Western Sahara  0.798044  0.783196  0.786200  0.755798  0.707729
# 192             Vietnam  0.592507  0.616837  0.612250  0.681069  0.767733
# 193              Zambia  0.253837  0.238964  0.181764  0.178273  0.182459
# 194            Zimbabwe  1.191934  1.162342  1.276289  1.110012  0.998965
#
#          2002      2003      2004      2005      2006      2007      2008  \
# ...

# %%
years1 = np.array(['2004', '2005', '2006', '2007', '2008', '2009', '2010'])
india = np.array(df[years1][df['CO2 per capita'].isin(['India'])])
pakistan = np.array(df[years1][df['CO2 per capita'].isin(['Pakistan'])])
plt.plot(years1, india[0])
plt.plot(years1, pakistan[0])
plt.show()

# %%
# for i in range(3):
#     countries = ['India', 'China' , 'USA', 'Canada']
    years2 = np.array(['2001','2002','2003','2004', '2005', '2006', '2007', '2008', '2009', '2010'])
    country = np.array(df[years2][df['CO2 per capita'].isin([countries[i]])])
    country.ndim
#     plt.pie(country, labels=years2)
#     plt.title(countries[i])
#     plt.show()
# Out:
#   Input In [15]
#     years2 = np.array(['2001','2002','2003','2004', '2005', '2006', '2007', '2008', '2009', '2010'])
#     ^
# IndentationError: unexpected indent

# %%
india = np.array(df[years][df['CO2 per capita'].isin(['India'])])
india
