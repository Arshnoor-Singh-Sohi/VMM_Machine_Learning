# %%
# !pip install numpy

# %%
import numpy

# %%
x = [1,2,3,4,5,6,7]
arr = numpy.array(x)
# print(arr)
arr //dump // done at end always
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
print(arr.dtype)
# Out:
# int32

# %%
arr2 = numpy.array([1,2.0,"hello"])
print(arr2.dtype)
# Out:
# <U32

# %% [markdown]
# ### Indexing an Array

# %%
arr[2]
# Out:
# 3

# %%
arr[-9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 arr[-9]
#
# IndexError: index -9 is out of bounds for axis 0 with size 7

# %%
arr[-3]
# Out:
# 5

# %%
for i in range(0, len(arr)):
    print(arr[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in arr:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ## Slicing through array

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
arr[0:5]
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr[0:5:2]
# Out:
# array([1, 3, 5])

# %%
arr[::-1]
# Out:
# array([7, 6, 5, 4, 3, 2, 1])

# %%
arr[5:1] //infinite loop
# Out:
# array([], dtype=int32)

# %%
print(type(arr)
# Out:
#   Input In [19]
#     print(type(arr)
#                    ^
# SyntaxError: unexpected EOF while parsing

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr.dtype) //datatype in an array
# Out:
# int32
